# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset Euro_2012_stats_TEAM

# %% [markdown]
# ### Step 3. Assign it to a variable called euro12.

# %%
euro_12 = pd.read_csv("Euro_2012_stats_TEAM.csv")

# %% [markdown]
# ### Step 4. Select only the Goal column.

# %%
euro_12.Goals
# Out:
# 0      4.0
# 1      4.0
# 2      4.0
# 3      5.0
# 4      3.0
# 5     10.0
# 6      5.0
# 7      6.0
# 8      2.0
# 9      2.0
# 10     6.0
# 11     1.0
# 12     5.0
# 13    12.0
# 14     5.0
# 15     2.0
# 16     NaN
# 17     NaN
# 18     NaN
# 19     NaN
# Name: Goals, dtype: float64

# %% [markdown]
# ### Step 5. How many team participated in the Euro2012?

# %%
euro_12.Team.count()
# Out:
# 17

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(euro_12.columns)
# Out:
# 35

# %% [markdown]
# ### Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

# %%
disciline = pd.DataFrame(euro_12[['Team', 'Yellow Cards', 'Red Cards']])
disciline
# Out:
#                                                  Team  Yellow Cards  Red Cards
# 0                                             Croatia           9.0        0.0
# 1                                      Czech Republic           7.0        0.0
# 2                                             Denmark           4.0        0.0
# 3                                             England           5.0        0.0
# 4                                              France           6.0        0.0
# 5                                             Germany           4.0        0.0
# 6                                              Greece           9.0        1.0
# 7                                               Italy          16.0        0.0
# 8                                         Netherlands           5.0        0.0
# 9                                              Poland           7.0        1.0
# 10                                           Portugal          12.0        0.0
# ...

# %% [markdown]
# ### Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
disciline.sort_values(['Red Cards','Yellow Cards'])
# Out:
#                                                  Team  Yellow Cards  Red Cards
# 2                                             Denmark           4.0        0.0
# 5                                             Germany           4.0        0.0
# 3                                             England           5.0        0.0
# 8                                         Netherlands           5.0        0.0
# 15                                            Ukraine           5.0        0.0
# 4                                              France           6.0        0.0
# 12                                             Russia           6.0        0.0
# 1                                      Czech Republic           7.0        0.0
# 14                                             Sweden           7.0        0.0
# 0                                             Croatia           9.0        0.0
# 13                                              Spain          11.0        0.0
# ...

# %% [markdown]
# ### Step 9. Calculate the mean Yellow Cards given per Team

# %%
euro_12['Yellow Cards'].mean()
# Out:
# 7.4375

# %% [markdown]
# ### Step 10. Filter teams that scored more than 6 goals

# %%
euro_12.filter(["Goals","Team"])[euro_12.Goals > 6]
# Out:
#     Goals     Team
# 5    10.0  Germany
# 13   12.0    Spain

# %% [markdown]
# ### Step 11. Select the teams that start with G

# %%
euro_12[5:7]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany   10.0             32.0              32.0            47.80%
# 6   Greece    5.0              8.0              18.0            30.70%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5           15.60%                        80.0           2.0            1.0
# 6           19.20%                        32.0           1.0            1.0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                   0.0  ...        10.0                62.60%       63.0
# 6                   1.0  ...        13.0                65.10%       67.0
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5           49.0      12.0           4.0        0.0     15.0      15.0
# 6           48.0      12.0           9.0        1.0     12.0      12.0
#
#    Players Used
# 5          17.0
# 6          20.0
#
# [2 rows x 35 columns]

# %% [markdown]
# ### Step 12. Select the first 7 columns

# %%
euro_12.iloc[:,:7]
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 13. Select all columns except the last 3.

# %%
euro_12.iloc[:,:-3]
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...

# %% [markdown]
# ### Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro_12.loc[[3,7,12] , ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England            50.00%
# 7     Italy            43.00%
# 12   Russia            22.50%

# %% [markdown]
# ### Step 15. Use apply method on Goal Column to make a new column called Performance, using following conditions
#
# 1. If Goals are less than or equal to 2, peformance is **Below Avg**
# 2. If Goals are more than 2 and less than or equal to 5, peformance is **Average**
# 3. If Goals are more than 5 and less than or equal to 10, peformance is **Above Average**
# 4. If Goals are more than 10 then peformance is **Excellent**

# %%
import pandas as pd
import numpy as np

def perf(g):
    if (g <= 2):
        return "Below Avg"
    
    if (g > 2 or g <= 5):
        return "Average"
    
    if (g > 5 or g <= 10):
        return "Above Average"
        
    return"Excellent"
g = euro_12.Goals.values
#euro_12['Performance'] = euro_12.apply(lambda g: perf(g))
euro_12['Performance'].perf(g)
euro_12
#f = lambda x: perf(g)
#Peformance = euro_12.apply(f)
#euro_12['Performance']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-e788cca386fa> in <module>
#      15 g = euro_12.Goals.values
#      16 #euro_12['Performance'] = euro_12.apply(lambda g: perf(g))
# ---> 17 euro_12['Performance'].perf(g)
#      18 euro_12
#      19 #f = lambda x: perf(g)
#
# E:\Anaconda\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'perf'

# %%
g = euro_12.Goals
def perf(g):
    if (g <= 2):
        print('Below Avg')
    
    elif (g > 2 or g <= 5):
        print('Average')
    
    elif np.where(g > 5 or g <= 10):
        print('Above Average')
        
    else: 
        print('Excellent')

#euro_12['Performance'] = euro_12.apply(lambda g: perf(g))
#euro_12['Performance'].perf(g)
euro_12['Peformance'] = euro_12.apply(perf)
euro_12
#f = lambda x: perf(g)
#euro_12['Performance']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-756cf5127dca> in <module>
#      15 #euro_12['Performance'] = euro_12.apply(lambda g: perf(g))
#      16 #euro_12['Performance'].perf(g)
# ---> 17 euro_12['Peformance'] = euro_12.apply(perf)
#      18 euro_12
#      19 #f = lambda x: perf(g)
#
# E:\Anaconda\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6911             kwds=kwds,
#    6912         )
# -> 6913         return op.get_result()
#    6914
#    6915     def applymap(self, func):
#
# E:\Anaconda\lib\site-packages\pandas\core\apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# ...
